# %%
#!/bin/python3

import math
import os
import random
import re
import sys

# Complete the miniMaxSum function below.
def miniMaxSum(arr):
    sorted_list = sorted(arr)
    min_sum = sum(sorted_list[:4])
    max_sum = sum(sorted_list[1:])
    print(min_sum, max_sum)
    
if __name__ == '__main__':
    arr = list(map(int, input().rstrip().split()))
    #print(arr)

    miniMaxSum(arr)

# %%
#!/bin/python3

import math
import os
import random
import re
import sys

# Complete the birthdayCakeCandles function below.
def birthdayCakeCandles(ar):
    sort_arr = sorted(ar)
    return sort_arr.count(sort_arr[-1])

if __name__ == '__main__':
    ar_count = int(input())

    ar = list(map(int, input().rstrip().split()))

    result = birthdayCakeCandles(ar)
    print(result)

# %%
#!/bin/python3

import math
import os
import random
import re
import sys

# Complete the plusMinus function below.
def plusMinus(arr):
    pos = 0
    neg = 0
    zero = 0
    for i in arr:
        if i < 0:
            neg = neg+1;
        elif i > 0:
            pos = pos+1;
        else:
            zero = zero+1
    print("{:.6f}".format(pos/len(arr)))
    print("{:.6f}".format(neg/len(arr)))
    print("{:.6f}".format(zero/len(arr)))
    #print("{:.6f}".format(your value here));

if __name__ == '__main__':
    n = int(input())

    arr = list(map(int, input().rstrip().split()))

    plusMinus(arr)

# %%
from datetime import datetime as dt
date_str='15:25:05'

#date_obj = dt.strptime(date_str, '%m/%d/%Y %H:%M:%S')

#dt.strftime(date_obj, '%m/%d/%Y %I:%M:%S %p')
date_obj = dt.strptime(date_str, '%H:%M:%S')
dt.strftime(date_obj, '%I:%M:%S %p')

# %% [markdown]
# ## Print even-odd alphabets

# %%
def even_odd(lst_words):
    for word in lst_words:
        print(*["".join(word[::2]),"".join(word[1::2])])

if __name__ == '__main__':
    n = int(input())
    words = []
    for i in range(n):
        words.append(input())
    
    even_odd(words)

# %% [markdown]
# ## Between Two sets

# %%
#!/bin/python3

import math
import os
import random
import re
import sys
import numpy as np

#
# Complete the 'getTotalX' function below.
#
# The function is expected to return an INTEGER.
# The function accepts following parameters:
#  1. INTEGER_ARRAY a
#  2. INTEGER_ARRAY b
#

def getTotalX(a, b):
    # Write your code here
    x = [i for i in range(max(a), min(b)+1)]
    x1 = []
    for num in x:
        count = 0
        for i in a:
            if(num % i == 0):
                count+=1
                if(count == len(a)):
                    x1.append(num)
    x2 = []
    for num in x1:
        count = 0
        for i in b:
            if i % num == 0:
                count +=1
                if count == len(b):
                    x2.append(num)
    return x2

if __name__ == '__main__':
    #fptr = open(os.environ['OUTPUT_PATH'], 'w')
    first_multiple_input = input().rstrip().split()
    n = int(first_multiple_input[0])
    m = int(first_multiple_input[1])
    arr = list(map(int, input().rstrip().split()))
    brr = list(map(int, input().rstrip().split()))
    total = getTotalX(arr, brr)
    print (total)
    #fptr.write(str(total) + '\n')
    #fptr.close()

# %% [markdown]
# ## Array of sunshine

# %%
# Print array in reverse in one separated by space

x = [1, 2, 3 , 4, 5]
print(' '.join(map(str, x[::-1])))

# %% [markdown]
# ## Breaking Records

# %%
#!/bin/python3

import math
import os
import random
import re
import sys

# Complete the breakingRecords function below.
def breakingRecords(scores):
    high = scores[0]
    count_high = 0
    low = scores[0]
    count_low = 0
    
    for play in scores:
        if play < low:
            count_low+=1
            low = play
        elif play > high:
            count_high+=1
            high = play
    result = [count_high, count_low]
    return result

if __name__ == '__main__':
    #fptr = open(os.environ['OUTPUT_PATH'], 'w')

    n = int(input())

    scores = list(map(int, input().rstrip().split()))

    result = breakingRecords(scores)
    print(result)

    #fptr.write(' '.join(map(str, result)))
    #fptr.write('\n')

    #fptr.close()

# %% [markdown]
# ## Birthday Chocolate

# %%
#!/bin/python3

import math
import os
import random
import re
import sys

# Complete the birthday function below.
def birthday(s, d, m):
    x = []
    for i in range(len(s)):
        sum = 0
        for j in range(i, i+m):
            if(j == len(s)):
                break
            sum = sum+s[j]
            if(j == (i+m)-1):
                x.append(sum)
            
            
    #return x.count(d)
    return x

if __name__ == '__main__':
    #fptr = open(os.environ['OUTPUT_PATH'], 'w')

    n = int(input().strip())

    s = list(map(int, input().rstrip().split()))

    dm = input().rstrip().split()

    d = int(dm[0])

    m = int(dm[1])

    result = birthday(s, d, m)
    
    print(result)

    #fptr.write(str(result) + '\n')

    #fptr.close()

# %% [markdown]
# ### Sliding Window approach

# %%
def birthday(s, d, m):
    window_sum = sum(s[:m])
    x = [window_sum]
    for i in range(len(s) - m):
        window_sum = window_sum - s[i] + s[i+m]
        x.append(window_sum)
    
    return x
if __name__ == '__main__':
    n = int(input().strip())
    s = list(map(int, input().rstrip().split()))
    dm = input().rstrip().split()
    d = int(dm[0])
    m = int(dm[1])
    result = birthday(s, d, m)
    print(result)

# %% [markdown]
# ## Day 8: Dictionaries and Maps

# %%
class_list = dict() 
y = input() 
temp = y.split(sep=' ') 
class_list[temp[0]] = int(temp[1]) 

print(temp[0])
#print(class_list)

# %%
if __name__ == '__main__':
    n = int(input())
    names = [input().split() for _ in range(n)]
    phone_book = {k:v for k,v in names}
    
    while True:
        try:
            query = input()
            if query in phone_book:
                print(phone_book[query])
            else:
                print('Not found')
        except EOFError:
            break

# %% [markdown]
# ## Divisible Sum Pairs

# %%
a = [1, 3, 2, 6, 1, 2]
x = []
for i in range(len(a)):
    for j in range(i+1, len(a)):
        x.append(a[i] + a[j])
count = 0
for i in x:
    if i%3 == 0:
        count+=1

# %% [markdown]
# ## Day 9: Recursion 3

# %%
def factorial(x):
    """This is a recursive function
    to find the factorial of an integer"""

    if x == 1:
        return 1
    else:
        return (x * factorial(x-1))


num = 3
print("The factorial of", num, "is", factorial(num))

# %%
#!/bin/python3

import math
import os
import random
import re
import sys

# Complete the factorial function below.
def factorial(n):
    if (n == 1):
        return 1
    else:
        return (n) * factorial(n-1)
    

if __name__ == '__main__':
    #fptr = open(os.environ['OUTPUT_PATH'], 'w')
    n = int(input())
    result = factorial(n)
    print(result)
    #fptr.write(str(result) + '\n')
    #fptr.close()

# %% [markdown]
# ## Day 10: Binary Numbers

# %%
n = int(input())
x = []
a = 0
b = 0
while(n>0):
    x.append(n%2)
    if(n%2 == 1):
        a+=1
        if(a >=b):
            b=a
    else:
        a=0
    n=int(n/2)
print(a)

# %% [markdown]
# ## Migratory Birds

# %%
x = [1, 2, 3, 4, 5, 4, 3, 2, 1, 3, 4]
a = dict()
for i in x:
    a[i] = x.count(i)

# %%
a[max(a.values()) in a.values()]

# %%
max(a.values()) in a.values()

# %%
input()
count = [0]*6
for t in map(int,input().strip().split()):
    count[t] += 1
print(count.index(max(count)))

# %%
#!/bin/python3

import math
import os
import random
import re
import sys

# Complete the migratoryBirds function below.
    
    
if __name__ == '__main__':
    #fptr = open(os.environ['OUTPUT_PATH'], 'w')
    n = input()
    a = [0]*6
    for i in map(int, input().strip().split()):
        a[i]+=1
    print(a.index(max(a)))

    
    
    #fptr.write(str(result) + '\n')

    #fptr.close()

# %% [markdown]
# ## Day 11: 2D Arrays

# %%
#!/bin/python3

import math
import os
import random
import re
import sys



if __name__ == '__main__':
    arr = []

    for _ in range(6):
        arr.append(list(map(int, input().rstrip().split())))

    temp_sum = 0
    max_sum = 0
    for i in range(4):
        for j in range(4):
            temp_sum = 0
            
            # top row
            temp_sum = temp_sum + arr[i][j]
            temp_sum = temp_sum + arr[i][j+1]
            temp_sum = temp_sum + arr[i][j+2]
            
            # middle
            temp_sum = temp_sum + arr[i+1][j+1]
            
            # bottpm row
            temp_sum = temp_sum + arr[i+2][j]
            temp_sum = temp_sum + arr[i+2][j+1]
            temp_sum = temp_sum + arr[i+2][j+2]
            
            if((temp_sum > max_sum) or (i == 0 and j == 0)):
                max_sum = temp_sum
    print(max_sum)

# %% [markdown]
# ## Day 12: Inheritance

# %%
class Person:
	def __init__(self, firstName, lastName, idNumber):
		self.firstName = firstName
		self.lastName = lastName
		self.idNumber = idNumber
	def printPerson(self):
		print("Name:", self.lastName + ",", self.firstName)
		print("ID:", self.idNumber)

# %%
class Student(Person):
    #   Class Constructor
    #   
    #   Parameters:
    #   firstName - A string denoting the Person's first name.
    #   lastName - A string denoting the Person's last name.
    #   id - An integer denoting the Person's ID number.
    #   scores - An array of integers denoting the Person's test scores.
    #
    # Write your constructor here
    def __init__(self, firstName, lastName, idNumber, scores):
        self.firstName = firstName
        self.lastName = lastName
        self.idNumber = idNumber
        self.scores = scores       
    
    #   Function Name: calculate
    #   Return: A character denoting the grade.
    #
    # Write your function here
    def calculate(self):
        avg_score = sum(self.scores)/len(self.scores)
        #print(avg_score)
        if(90 <= avg_score <= 100):
            return 'O'
        elif(80 <= avg_score < 90):
            return 'E'
        elif(70 <= avg_score < 80):
            return 'A'
        elif(55 <= avg_score < 70):
            return 'P'
        elif(40 <= avg_score < 55):
            return 'D'
        elif(avg_score < 40):
            return 'T'

# %%
line = input().split()
firstName = line[0]
lastName = line[1]
idNum = line[2]
numScores = int(input()) # not needed for Python
scores = list( map(int, input().split()) )
s = Student(firstName, lastName, idNum, scores)
s.printPerson()
print("Grade:", s.calculate())

# %% [markdown]
# ## Day of the Programmer

# %%
#!/bin/python3

import math
import os
import random
import re
import sys

# Complete the dayOfProgrammer function below.
def dayOfProgrammer(year):
    if(year <= 1918):
        if(year % 4 == 0):
            return ('12.09.{}'.format(year))
        else:
            return ('13.09.{}'.format(year))

    if(year > 1918):
        if (year % 4) == 0:
            if (year % 100) == 0:
                if (year % 400) == 0:
                    return ('12.09.{}'.format(year))
                else:
                    return ('13.09.{}'.format(year))
            else:
                return ('12.09.{}'.format(year))
        else:
            return ('13.09.{}'.format(year))
if __name__ == '__main__':
    #fptr = open(os.environ['OUTPUT_PATH'], 'w')

    year = int(input().strip())

    result = dayOfProgrammer(year)
    print(result)

    #fptr.write(result + '\n')

    #fptr.close()

# %% [markdown]
# ## Bon Appétit

# %%
b = [3, 10, 2, 9]
a = b.copy()
a.remove(b[1])
anna = sum(a)/2
brian = sum(b)/2
if(anna == brian):
    print('Bon Appetit')
else:
    print(int(brian - anna))

# %% [markdown]
# ## Day 13: Abstract Classes

# %%
from abc import ABCMeta, abstractmethod
class Book(object, metaclass=ABCMeta):
    def __init__(self,title,author):
        self.title=title
        self.author=author   
    @abstractmethod
    def display(): pass

#Write MyBook class
class MyBook(Book):
    def __init__(self, title, author, price):
        self.title = title
        self.author = author
        self.price = price

    def display(self):
        print("Title: {}".format(self.title))
        print("Author: {}".format(self.author))
        print("Price: {}".format(self.price))
        
title=input()
author=input()
price=int(input())
new_novel=MyBook(title,author,price)
new_novel.display()

# %% [markdown]
# ## Day 14: Scope

# %%
class Difference:
    def __init__(self, a):
        self.__elements = a

    # Add your code here
    def computeDifference(self):
        self.maximumDifference = max(self.__elements) - min(self.__elements)
# End of Difference class

_ = input()
a = [int(e) for e in input().split(' ')]

d = Difference(a)
d.computeDifference()

print(d.maximumDifference)

# %% [markdown]
# ## Sock Merchant

# %%
x = [1, 1, 1, 2, 2, 2, 3]
thisdict = dict.fromkeys(x, 0)
thisdict

# %%
dir(list)

# %%
#!/bin/python3

import math
import os
import random
import re
import sys

# Complete the sockMerchant function below.
def sockMerchant(n, ar):
    pair = 0
    x = []
    for i in range(n):
        if(ar[i] not in x):
            x.append(ar[i])
        else:
            pair+=1
            x.remove(ar[i])
    return pair
    

if __name__ == '__main__':
    #fptr = open(os.environ['OUTPUT_PATH'], 'w')

    n = int(input())

    ar = list(map(int, input().rstrip().split()))

    result = sockMerchant(n, ar)
    print(result)

    #fptr.write(str(result) + '\n')

    #fptr.close()

# %% [markdown]
# ## Drawing Book

# %%
#!/bin/python3

import os
import sys

#
# Complete the pageCount function below.
#
def pageCount(n, p):
    #
    # Write your code here.
    #
    return min(int(p/2), int(n/2 - p/2))

if __name__ == '__main__':
    #fptr = open(os.environ['OUTPUT_PATH'], 'w')

    n = int(input())

    p = int(input())

    result = pageCount(n, p)
    
    print(result)

    #fptr.write(str(result) + '\n')

    #fptr.close()

# %% [markdown]
# ## Counting Valleys

# %%
# Function to calculate cumulatve sum of a list
def cumsum(inp):
    cusum = []
    for i in range(len(inp)):
        if(i == 0):
            cusum.append(inp[i])
        else:
            cusum.append(sum(inp[:i]) + inp[i])
    return cusum

# %%
# Get the all the indices of input value in the list
def index_of(inp_list, value):
    indices = []
    for i in range(len(inp_list)):
        if(inp_list[i] == value):
            indices.append(i)
    return indices

# %%
s = 'DDUUDDUDUUUD'
y = [1 if s[i] == 'U' else -1 for i in range(len(s))]
cum_sum = cumsum(y)

indices_of_0 = index_of(cum_sum, 0)

sum_in_bwn = []
sum_in_bwn.append(sum(cum_sum[:indices_of_0[0]]))
sum_in_bwn.append(sum(cum_sum[indices_of_0[-1]:]))
for i in range(len(indices_of_0)-1):
    sum_in_bwn.append(sum(cum_sum[indices_of_0[i] : indices_of_0[i+1]]))

# Valley Count
valley_count = 0
for i in sum_in_bwn:
    if(i < 0):
        valley_count +=1
        
print(valley_count)

# %% [markdown]
# ### Alternative : 1

# %%
s = '...'

# %%
#s = 'DDUUDDUDUUUD'

sealevel = 0
valley = 0
for step in s:
    if(step == 'U'):
        sealevel +=1
    else:
        sealevel -=1
    if step == 'U' and sealevel == 0:
        valley +=1
        
print(valley)

# %% [markdown]
# ### Alternative : 2

# %%
def countingValleys(n, s):
    a,b = 0,0
    d = {"U":1, "D":-1}
    for i in s:
        if not a+d[i] and a<0:
            b+=1
        a+=d[i]
    return b
#n,s = input(),input()

print(countingValleys(n, s))

# %% [markdown]
# ## Day 15: Linked List

# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.next = None 
class Solution: 
    def display(self,head):
        current = head
        while current:
            print(current.data,end=' ')
            current = current.next

    def insert(self,head,data):
        #Complete this method
        if(head == None):
            head_node = Node(data)
            return head_node
        new_node = Node(data)
        curr = head
        while(curr.next):
            curr = curr.next
        curr.next = new_node
        return head
       
mylist= Solution()
T=int(input())
head=None
for i in range(T):
    data=int(input())
    head=mylist.insert(head,data)    
mylist.display(head);

# %% [markdown]
# ## Electronics Shop

# %%
#!/bin/python3

import os
import sys

#
# Complete the getMoneySpent function below.
#
def getMoneySpent_1(keyboards, drives, b):
    #
    # Write your code here.
    #
    expenditure = []
    for i in keyboards:
        for j in drives:
            expenditure.append(i+j)
    expenditure.sort(reverse = True)
    #print(expenditure)
    for i in expenditure:
        if(i<=b):
            return i
    return -1

def getMoneySpent(keyboards, drives, s):
        temp = max([sum([x,y]) for x in keyboards for y in drives if sum([x,y]) <= s]+[-1])
        #print(temp)
        return temp

if __name__ == '__main__':
    #fptr = open(os.environ['OUTPUT_PATH'], 'w')
    bnm = input().split()
    b = int(bnm[0])
    n = int(bnm[1])
    m = int(bnm[2])
    
    keyboards = list(map(int, input().rstrip().split()))
    
    drives = list(map(int, input().rstrip().split()))
    
    moneySpent = getMoneySpent(keyboards, drives, b)
    
    print(moneySpent)
    #fptr.write(str(moneySpent) + '\n')
    #fptr.close()

# %% [markdown]
# ## Day 16: Exceptions - String to Integer

# %%
while True:
    try:
        x = int(input("Please enter a number: "))
        break
    except ValueError:
        print("Bad input")

# %% [markdown]
# ## Cats and a Mouse

# %%
#!/bin/python3

import math
import os
import random
import re
import sys

# Complete the catAndMouse function below.
def catAndMouse(x, y, z):
    a = abs(x-z)
    b = abs(y-z)
    return "Cat A" if a<b else "Cat B" if a>b else "Mouse C"

if __name__ == '__main__':
    #fptr = open(os.environ['OUTPUT_PATH'], 'w')
    q = int(input())
    for q_itr in range(q):
        xyz = input().split()
        x = int(xyz[0])
        y = int(xyz[1])
        z = int(xyz[2])
        result = catAndMouse(x, y, z)
        print(result)
        #fptr.write(result + '\n')
    #fptr.close()

# %% [markdown]
# ## Day 17: More Exceptions

# %%
#Write your code here

class Calculator:
    def power(self, n, p):
        self.n = n
        self.p = p
        if((self.n < 0) or (self.p < 0)):
            raise ValueError("n and p should be non-negative") 
        return(self.n**self.p)

myCalculator=Calculator()
T=int(input())
for i in range(T):
    n,p = map(int, input().split())
    try:
        ans=myCalculator.power(n,p)
        print(ans)
    except Exception as e:
        print(e)

# %% [markdown]
# ## Forming a Magic Square

# %%
pre = [
        [[8, 1, 6], [3, 5, 7], [4, 9, 2]],
        [[6, 1, 8], [7, 5, 3], [2, 9, 4]],
        [[4, 9, 2], [3, 5, 7], [8, 1, 6]],
        [[2, 9, 4], [7, 5, 3], [6, 1, 8]], 
        [[8, 3, 4], [1, 5, 9], [6, 7, 2]],
        [[4, 3, 8], [9, 5, 1], [2, 7, 6]], 
        [[6, 7, 2], [1, 5, 9], [8, 3, 4]], 
        [[2, 7, 6], [9, 5, 1], [4, 3, 8]],
        ]

def evaluate(self, s):
    totals = []
    for p in pre:
        X = 0
        for p_row, s_row in zip(p, s):
            for i, j in zip(p_row, s_row):
                if i != j:
                    X += max([i, j]) - min([i, j])
        totals.append(X)
    return min(totals)

# %% [markdown]
# ## Day 18: Queues and Stacks

# %%
import sys

class Solution:
    # Write your code here
    def __init__(self):
        self.stack = []
        self.queue = []
    def pushCharacter(self, data):
        self.stack.append(data)
    
    def enqueueCharacter(self, data):
        self.queue.append(data)
        
    def popCharacter(self):
        char = self.stack.pop()
        return char
    
    def dequeueCharacter(self):
        char = self.queue[0]
        self.queue.remove(self.queue[0])
        return char        
        
        

# read the string s
s=input()
#Create the Solution class object
obj=Solution()   

l=len(s)
# push/enqueue all the characters of string s to stack
for i in range(l):
    obj.pushCharacter(s[i])
    obj.enqueueCharacter(s[i])
    
isPalindrome=True
'''
pop the top character from stack
dequeue the first character from queue
compare both the characters
''' 
for i in range(l // 2):
    if obj.popCharacter()!=obj.dequeueCharacter():
        isPalindrome=False
        break
#finally print whether string s is palindrome or not.
if isPalindrome:
    print("The word, "+s+", is a palindrome.")
else:
    print("The word, "+s+", is not a palindrome.")

# %% [markdown]
# ## Day 19: Interfaces

# %%
class AdvancedArithmetic(object):
    def divisorSum(n):
        raise NotImplementedError

class Calculator(AdvancedArithmetic):
    def divisorSum(self, n):
        sum_ = 0
        for i in range(1, n+1):
            if(n%i == 0):
                sum_+=i
        return sum_       


n = int(input())
my_calculator = Calculator()
s = my_calculator.divisorSum(n)
print("I implemented: " + type(my_calculator).__bases__[0].__name__)
print(s)

# %% [markdown]
# ## Picking Numbers

# %%
#!/bin/python3

import math
import os
import random
import re
import sys

#
# Complete the 'pickingNumbers' function below.
#
# The function is expected to return an INTEGER.
# The function accepts INTEGER_ARRAY a as parameter.
#

def pickingNumbers(a):
    # Write your code here
    maximum = []
    for i in a:
        c = a.count(i)
        d = a.count(i-1)
        maximum.append(c+d)
    return max(maximum)
    
if __name__ == '__main__':
    n = int(input().strip())
    a = list(map(int, input().rstrip().split()))
    result = pickingNumbers(a)
    print(result)

# %% [markdown]
# ## Climbing the Leaderboard

# %%
## !/bin/python3

import math
import os
import random
import re
import sys

#
# Complete the 'climbingLeaderboard' function below.
#
# The function is expected to return an INTEGER_ARRAY.
# The function accepts following parameters:
#  1. INTEGER_ARRAY ranked
#  2. INTEGER_ARRAY player
#

def climbingLeaderboard(ranked, player):
    # Write your code here
    ranked_new = list(set(ranked))
    ranked_new.sort(reverse = True)
    l = len(ranked_new)
    for s in player:
        while (l>0) and (s >= ranked_new[l-1]):
            l-=1
        result.append(l+1)
    return result
        

if __name__ == '__main__':
    #fptr = open(os.environ['OUTPUT_PATH'], 'w')

    ranked_count = int(input().strip())

    ranked = list(map(int, input().rstrip().split()))

    player_count = int(input().strip())

    player = list(map(int, input().rstrip().split()))

    result = climbingLeaderboard(ranked, player)
    print(result)

    #fptr.write('\n'.join(map(str, result)))
    #fptr.write('\n')

    #fptr.close()

# %% [markdown]
# ## Day 20: Sorting

# %%
#!/bin/python3

import sys

n = int(input().strip())
a = list(map(int, input().strip().split(' ')))
# Write Your Code Here

def swaps(a, b):
    x = a
    a = b
    b = x
    return a, b
    
swaps = 0
for i in range(n):
    swap_cnt = 0
    for j in range(n-1):
        if(a[j] > a[j+1]):
            a[j], a[j+1] = swap(a[j], a[j+1])
            swap_cnt+=1
            swaps+=1

    if(swap_cnt == 0):
        print('Array is sorted in {} swaps.'.format(swaps))
        print('First Element: {}'.format(a[0]))
        print('Last Element: {}'.format(a[-1]))

# %% [markdown]
# ## The Hurdle Race

# %%
#!/bin/python3

import math
import os
import random
import re
import sys

# Complete the hurdleRace function below.
def hurdleRace(k, height):
    return (max(max(height) - k, 0))

if __name__ == '__main__':
    #fptr = open(os.environ['OUTPUT_PATH'], 'w')

    nk = input().split()

    n = int(nk[0])

    k = int(nk[1])

    height = list(map(int, input().rstrip().split()))

    result = hurdleRace(k, height)
    
    print(result)

    #fptr.write(str(result) + '\n')

    #fptr.close()

# %% [markdown]
# ## Designer PDF Viewer

# %%
#!/bin/python3

import math
import os
import random
import re
import sys

# Complete the designerPdfViewer function below.
def designerPdfViewer(h, word):
    maximum = 0
    for char in word:
        if h[ord(char)-97] > maximum:
            maximum = h[ord(char) - ord('a')]
    return maximum * len(word)

if __name__ == '__main__':
    #fptr = open(os.environ['OUTPUT_PATH'], 'w')

    h = list(map(int, input().rstrip().split()))

    word = input()

    result = designerPdfViewer(h, word)
    
    print(result)

    #fptr.write(str(result) + '\n')

    #fptr.close()

# %% [markdown]
# ## Utopian Tree

# %%
#!/bin/python3

import math
import os
import random
import re
import sys

# Complete the utopianTree function below.
def utopianTree_1(n):
    H = [1]
    for i in range(1, n+1):
        if(i%2 != 0):
            H.append(2 * H[i-1])
        else:
            H.append(H[i-1]+1)
    return (H[-1])

def utopianTree(n):
    H = 1
    for i in range(1, n+1):
        if(i%2 != 0):
            H = 2*H
        else:
            H = H+1
    return H
if __name__ == '__main__':
    #fptr = open(os.environ['OUTPUT_PATH'], 'w')

    t = int(input())

    for t_itr in range(t):
        n = int(input())

        result = utopianTree(n)
        
        print(result)

        #fptr.write(str(result) + '\n')

    #fptr.close()

# %% [markdown]
# ## Angry Professor

# %%
#!/bin/python3

import math
import os
import random
import re
import sys

# Complete the angryProfessor function below.
def angryProfessor(k, a):
    if((len(a) - len([a.count(i) for i in a if i > 0])) >= k):
        return 'NO'
    else:
        return 'YES'

if __name__ == '__main__':
    #fptr = open(os.environ['OUTPUT_PATH'], 'w')

    t = int(input())

    for t_itr in range(t):
        nk = input().split()

        n = int(nk[0])

        k = int(nk[1])

        a = list(map(int, input().rstrip().split()))

        result = angryProfessor(k, a)
        
        print(result)

        #fptr.write(result + '\n')

    #fptr.close()

# %% [markdown]
# ## Day 22: Binary Search Trees

# %%
class Node:
    def __init__(self,data):
        self.right=self.left=None
        self.data = data
class Solution:
    def insert(self,root,data):
        if root==None:
            return Node(data)
        else:
            if data<=root.data:
                cur=self.insert(root.left,data)
                root.left=cur
            else:
                cur=self.insert(root.right,data)
                root.right=cur
        return root

    def getHeight(self,root):
        if root == None:
            return -1
        else:
            return (1+max(self.getHeight(root.left), self.getHeight(root.right)))

T=int(input())
myTree=Solution()
root=None
for i in range(T):
    data=int(input())
    root=myTree.insert(root,data)
height=myTree.getHeight(root)
print(height)

# %% [markdown]
# ## Day 23: BST Level-Order Traversal

# %%
import sys

class Node:
    def __init__(self,data):
        self.right=self.left=None
        self.data = data
class Solution:
    def insert(self,root,data):
        if root==None:
            return Node(data)
        else:
            if data<=root.data:
                cur=self.insert(root.left,data)
                root.left=cur
            else:
                cur=self.insert(root.right,data)
                root.right=cur
        return root
    
    def levelOrder(self,root):
        q = [root] if root else []
        
        while q:
            node = q.pop()
            print(node.data, end = ' ')
            
            if node.left:
                q.insert(0, node.left)
            if node.right:
                q.insert(0, node.right)
    
T=int(input())
myTree=Solution()
root=None
for i in range(T):
    data=int(input())
    root=myTree.insert(root,data)
myTree.levelOrder(root)

# %% [markdown]
# ## Day 24: More Linked Lists

# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.next = None 
class Solution: 
    def insert(self,head,data):
            p = Node(data)
            if head==None:
                head=p
            elif head.next==None:
                head.next=p
            else:
                start=head
                while(start.next!=None):
                    start=start.next
                start.next=p
            return head  
    def display(self,head):
        current = head
        while current:
            print(current.data,end=' ')
            current = current.next

    def removeDuplicates(self,head):
        start = head
        element = start.next
        values = []
        while(element):
            if(start.data not in values):
                values.append(start.data)
            if(element.data in values):
                start.next = element.next
                element = element.next
                continue
            start = element
            element = element.next
        return head
        
mylist= Solution()
T=int(input())
head=None
for i in range(T):
    data=int(input())
    head=mylist.insert(head,data)    
head=mylist.removeDuplicates(head)
mylist.display(head);
# Out:
# 5
# 1
# 1
# 1
# 1
# 1
# 1
